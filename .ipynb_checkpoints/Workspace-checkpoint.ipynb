# %%
import importlib
import utils
importlib.reload(utils)
from utils import SQLConnect, SimFin_DataRequestor, roic
importlib.reload(roic)

import requests
from matplotlib import pyplot as plt

import pandas as pd
API_KEY = 'N8XsZtAZtjMH8aUVK0d4A6HXm152V0TF'

# %%
sqlconnect = SQLConnect.SQLConnect()

# %%
query_str = """SELECT * FROM SimFin.vw_InvestedCapital t (nolock)"""
ic_df = pd.read_sql(query_str, sqlconnect.conn)
query_str = """SELECT * FROM SimFin.vw_EBIT t (NOLOCK)"""
ebit_df = pd.read_sql(query_str, sqlconnect.conn)
print(ic_df.shape)
print(ebit_df.shape)
# Out:
# (11186, 5)
# (12071, 5)

# %%
sectorName = 'Oil & Gas - E&P'

simIds_query_str = """
SELECT DISTINCT simId
FROM SimFin.general_company_data (nolock)
WHERE
    sectorName = '%s'
""" % sectorName

simIds_query_str = """
SELECT DISTINCT simId
FROM SimFin.general_company_data (nolock)
where sectorname is null"""

# %%
simIds = [simId for simId in pd.read_sql(simIds_query_str, sqlconnect.conn).simId]

# %%
prices_querystr = """
SELECT *
FROM SimFin.vw_fyearEnd_Prices
WHERE simId = %s"""

columns = ['simId_x', 'ticker_x', 'sectorName', 'fyear', 'filing_date', 
           'Invested Capital', 'Avg_Invested_Capital', 
           'EBIT', 'ROIC', 'closeAdj_at_filing_date']

data = []
n_ids = len(simIds)
for i, simId in enumerate(simIds):
    if not (i+1) % 5: print("%d/%d" % (i+1, n_ids))
    df = roic.return_roic_df([simId], ic_df, ebit_df)
    df2 = pd.read_sql(prices_querystr % simId, sqlconnect.conn)#[['simId', 'ticker', 'fyear']]
   
    try:
        df = df.merge(df2, left_on = 'fiscal_year', right_on='fyear')[columns]
    except:
        print("Can't merge")
        continue
    
    df['pct_change_fwd'] = df.closeAdj_at_filing_date.pct_change().shift(-1)
    df['pct_change_fwd2'] = df.closeAdj_at_filing_date.pct_change(2).shift(-2)
    df['pct_change_fwd3'] = df.closeAdj_at_filing_date.pct_change(2).shift(-3)
#     df = df.dropna()
    
    if not df.empty:
        data.append(df)
        
print('\nDone')
# Out:
# Can't merge
# Can't merge
# 5/340
# Can't merge
# 10/340
# Can't merge
# 15/340
# Can't merge
# 20/340
# Can't merge
# 25/340
# 30/340
# Can't merge
# 35/340
# Can't merge
# Can't merge
# 40/340
# Can't merge
# 45/340
# Can't merge
# 50/340
# 55/340
# Can't merge
# Can't merge
# Can't merge
# 60/340
# Can't merge
# Can't merge
# Can't merge
# 65/340
# Can't merge
# 70/340
# Can't merge
# 75/340
# 80/340
# 85/340
# 90/340
# Can't merge
# 95/340
# 100/340
# 105/340
# Can't merge
# 110/340
# Can't merge
# 115/340
# 120/340
# 125/340
# Can't merge
# Can't merge
# 130/340
# Can't merge
# 135/340
# 140/340
# Can't merge
# 145/340
# Can't merge
# 150/340
# 155/340
# 160/340
# 165/340
# Can't merge
# 170/340
# 175/340
# Can't merge
# Can't merge
# 180/340
# Can't merge
# 185/340
# Can't merge
# Can't merge
# Can't merge
# Can't merge
# 190/340
# 195/340
# Can't merge
# 200/340
# 205/340
# Can't merge
# 210/340
# 215/340
# Can't merge
# Can't merge
# Can't merge
# 220/340
# 225/340
# ...

# %%
result = pd.concat(data, axis = 0)
result = result[result['Avg_Invested_Capital'] > 0]
print(result.shape)
result.head()
# Out:
# (435, 13)
#    simId_x ticker_x sectorName  fyear filing_date  Invested Capital  \
# 0    39382      JOY       None   2009  2009-12-31        2101286000
# 1    39382      JOY       None   2010  2010-12-31        2249239000
# 2    39382      JOY       None   2011  2011-12-30        3765005000
# 3    39382      JOY       None   2012  2012-12-31        4440149000
# 4    39382      JOY       None   2013  2013-12-31        4499345000
#
#    Avg_Invested_Capital        EBIT      ROIC  closeAdj_at_filing_date  \
# 0          1.815854e+09   702312000  0.386767                    47.65
# 1          2.175262e+09   697103000  0.320468                    81.10
# 2          3.007122e+09   920179000  0.306000                    70.63
# 3          4.102577e+09  1172559000  0.285810                    60.79
# 4          4.469747e+09   990630000  0.221630                    56.46
#
#    pct_change_fwd  pct_change_fwd2  pct_change_fwd3
# 0        0.701994         0.482267        -0.250432
# ...

# %%
result = result[result['ROIC'] >= -1]
result = result[result['ROIC'] <= 2]
result = result[result['pct_change_fwd'] <= 2]
result.plot(x='ROIC', y='pct_change_fwd', kind='scatter')

# %%
result.sort_values(by = 'ROIC', ascending=False)
# Out:
#     simId_x ticker_x sectorName  fyear filing_date  Invested Capital  \
# 2    544026      OCN      Banks   2013  2014-02-28        3650621000
# 4    544026      OCN      Banks   2015  2016-02-29        1962560000
# 1    544026      OCN      Banks   2012  2013-02-28        2555165000
# 3    544026      OCN      Banks   2014  2015-02-27        3124856000
# 0    544026      OCN      Banks   2011  2012-02-29        1966234000
# 3    537548     PACW      Banks   2014  2015-02-27       16234605000
# 4    135823     OZRK      Banks   2015  2016-02-29        9879459000
# 3    135823     OZRK      Banks   2014  2015-02-27        6766499000
# 4    537548     PACW      Banks   2015  2016-02-29       21288490000
# 2    135823     OZRK      Banks   2013  2014-02-28        4791170000
# 0    129536     NKSH      Banks   2011  2012-02-29        1067102000
# 1    135823     OZRK      Banks   2012  2013-02-28        4040207000
# 1    129536     NKSH      Banks   2012  2013-02-28        1104361000
# ...
